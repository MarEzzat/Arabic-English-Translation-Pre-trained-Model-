# %%
# !pip install transformers datasets evaluate --quiet
# !pip install sacrebleu
# !pip install sacremoses
#Download dataset from GitHub
# !wget https://raw.githubusercontent.com/SamirMoustafa/nmt-with-attention-for-ar-to-en/master/ara_.txt -O ara_eng.txt
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 9.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 11.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 10.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 8.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-cupti-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-cupti-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-nvrtc-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-nvrtc-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-runtime-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-runtime-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cudnn-cu12 9.3.0.75 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cufft-cu12==11.2.1.3; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cufft-cu12 11.2.3.61 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-curand-cu12==10.3.5.147; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-curand-cu12 10.3.6.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusolver-cu12==11.6.1.9; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusolver-cu12 11.6.3.83 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusparse-cu12==12.3.1.170; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusparse-cu12 12.5.1.3 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-nvjitlink-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-nvjitlink-cu12 12.5.82 which is incompatible.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.
# Collecting sacrebleu
#   Downloading sacrebleu-2.5.1-py3-none-any.whl.metadata (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 3.6 MB/s eta 0:00:00
# Collecting portalocker (from sacrebleu)
#   Downloading portalocker-3.1.1-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (2024.11.6)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (2.0.2)
# Collecting colorama (from sacrebleu)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (5.4.0)
# Downloading sacrebleu-2.5.1-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 8.3 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading portalocker-3.1.1-py3-none-any.whl (19 kB)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.6 portalocker-3.1.1 sacrebleu-2.5.1
# Collecting sacremoses
#   Downloading sacremoses-0.1.1-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from sacremoses) (2024.11.6)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from sacremoses) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from sacremoses) (1.4.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from sacremoses) (4.67.1)
# Downloading sacremoses-0.1.1-py3-none-any.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 15.4 MB/s eta 0:00:00
# Installing collected packages: sacremoses
# Successfully installed sacremoses-0.1.1
# --2025-05-12 14:05:34--  https://raw.githubusercontent.com/SamirMoustafa/nmt-with-attention-for-ar-to-en/master/ara_.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 763396 (746K) [text/plain]
# Saving to: ‘ara_eng.txt’
#
# ara_eng.txt         100%[===================>] 745.50K  --.-KB/s    in 0.04s
#
# 2025-05-12 14:05:34 (17.7 MB/s) - ‘ara_eng.txt’ saved [763396/763396]

# %%
# Needed libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from datasets import Dataset
import re
import evaluate
from transformers import (
    MarianMTModel,
    MarianTokenizer,
    Seq2SeqTrainer,
    Seq2SeqTrainingArguments,
)
import torch
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# %%
# Check GPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
with open("ara_eng.txt", "r", encoding="utf-8") as f:
    for i in range(10):
        print(f.readline())
# Out:
# Hi.	مرحبًا.
#
# Run!	اركض!
#
# Help!	النجدة!
#
# Jump!	اقفز!
#
# Stop!	قف!
#
# Go on.	داوم.
#
# Go on.	استمر.
#
# Hello!	مرحباً.
#
# Hurry!	تعجّل!
#
# Hurry!	استعجل!

# %%
# Clean text
def clean_text(text):
    if not isinstance(text, str):
        return ""

    diacritics_pattern = re.compile(r'[\u064B-\u065F]')
    text = re.sub(diacritics_pattern, '', text)
    text = text.replace("ى", "ي").replace("ة", "ه").replace("ؤ", "و")
    text = text.replace("إ", "ا").replace("أ", "ا").replace("آ", "ا").replace("ئ", "ي")
    text = text.replace("ـ", "")
    text = re.sub(r'[^\u0600-\u06FF\s؟!.،]', '', text)  # Keep Arabic letters + punctuation
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# Load dataset
data = pd.read_csv("ara_eng.txt", sep='\t', header=None, names=["English", "Arabic"])
data.dropna(inplace=True)
data["Arabic"] = data["Arabic"].apply(clean_text)
data = data[data["Arabic"].str.strip() != ""]

data["English"] = data["English"].str.strip()

# Split data
train_data, test_data = train_test_split(data, test_size=0.2, random_state=42)

train_data = train_data.reset_index(drop=True)
test_data = test_data.reset_index(drop=True)

# To Hugging Face Datasets
train_dataset = Dataset.from_pandas(train_data.reset_index(drop=True))
test_dataset = Dataset.from_pandas(test_data.reset_index(drop=True))

# %%
# Load model and tokenizer
model_name = "Helsinki-NLP/opus-mt-ar-en"
tokenizer = MarianTokenizer.from_pretrained(model_name)
tokenizer.padding_side = "right"
model = MarianMTModel.from_pretrained(model_name)

# Tokenization
def tokenize_function(examples):
    model_inputs = tokenizer(
        examples["Arabic"],
        max_length=256,
        padding="max_length",
        truncation=True
    )
    with tokenizer.as_target_tokenizer():
        labels = tokenizer(
            examples["English"],
            max_length=256,
            padding="max_length",
            truncation=True
        )
    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# Tokenize
train_dataset = train_dataset.map(tokenize_function, batched=True)
test_dataset = test_dataset.map(tokenize_function, batched=True)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/917k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/802k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.13M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/308M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# Map:   0%|          | 0/8593 [00:00<?, ? examples/s]
# /usr/local/lib/python3.11/dist-packages/transformers/tokenization_utils_base.py:3980: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/308M [00:00<?, ?B/s]
# Map:   0%|          | 0/2149 [00:00<?, ? examples/s]

# %%
# Training args
training_args = Seq2SeqTrainingArguments(
    output_dir="./results",
    per_device_train_batch_size=6,
    per_device_eval_batch_size=6,
    num_train_epochs=10,
    logging_dir="./logs",
    logging_steps=50,
    save_strategy="no",
    predict_with_generate=True,
    report_to="none",
)

# Trainer
trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    tokenizer=tokenizer,
)

trainer.train()
# Out:
# <ipython-input-7-72a1c827f6db>:15: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Seq2SeqTrainer.__init__`. Use `processing_class` instead.
#   trainer = Seq2SeqTrainer(
#     <div>
#
#       <progress value='13485' max='14330' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [13485/14330 1:03:57 < 04:00, 3.51 it/s, Epoch 9.41/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>1.377500</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.022600</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.022400</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.022500</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.020400</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.020000</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.021700</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.019900</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.020200</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.021300</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.022300</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.023800</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>0.021000</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.021700</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>0.022000</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.023400</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>0.021500</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.021100</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>0.020400</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.022700</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>0.019800</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.019400</td>
#     </tr>
#     <tr>
#       <td>1150</td>
#       <td>0.019300</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.019900</td>
#     </tr>
#     <tr>
#       <td>1250</td>
#       <td>0.021900</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.020100</td>
#     </tr>
#     <tr>
#       <td>1350</td>
#       <td>0.017600</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.017700</td>
#     </tr>
#     <tr>
#       <td>1450</td>
#       <td>0.016900</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.010000</td>
#     </tr>
#     <tr>
#       <td>1550</td>
#       <td>0.012700</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.010300</td>
#     </tr>
#     <tr>
#       <td>1650</td>
#       <td>0.009600</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.010600</td>
#     </tr>
#     <tr>
#       <td>1750</td>
#       <td>0.010000</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.009900</td>
#     </tr>
#     <tr>
#       <td>1850</td>
#       <td>0.011100</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>0.009600</td>
#     </tr>
#     <tr>
#       <td>1950</td>
#       <td>0.011000</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.011900</td>
#     </tr>
#     <tr>
#       <td>2050</td>
#       <td>0.010100</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.010100</td>
#     </tr>
#     <tr>
#       <td>2150</td>
#       <td>0.010800</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>0.011500</td>
#     </tr>
#     <tr>
#       <td>2250</td>
#       <td>0.011300</td>
#     </tr>
#     <tr>
#       <td>2300</td>
#       <td>0.012200</td>
#     </tr>
#     <tr>
#       <td>2350</td>
#       <td>0.011200</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>0.011200</td>
#     </tr>
#     <tr>
#       <td>2450</td>
#       <td>0.011900</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.012500</td>
#     </tr>
#     <tr>
#       <td>2550</td>
#       <td>0.012100</td>
#     </tr>
#     <tr>
#       <td>2600</td>
#       <td>0.010900</td>
#     </tr>
#     <tr>
#       <td>2650</td>
#       <td>0.012200</td>
#     </tr>
#     <tr>
#       <td>2700</td>
#       <td>0.011100</td>
#     </tr>
#     <tr>
#       <td>2750</td>
#       <td>0.010600</td>
#     </tr>
#     <tr>
#       <td>2800</td>
#       <td>0.012900</td>
#     </tr>
#     <tr>
#       <td>2850</td>
#       <td>0.010500</td>
#     </tr>
#     <tr>
#       <td>2900</td>
#       <td>0.007400</td>
#     </tr>
#     <tr>
#       <td>2950</td>
#       <td>0.006700</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.007300</td>
#     </tr>
#     <tr>
#       <td>3050</td>
#       <td>0.007000</td>
#     </tr>
#     <tr>
#       <td>3100</td>
#       <td>0.005300</td>
#     </tr>
#     <tr>
#       <td>3150</td>
#       <td>0.005600</td>
#     </tr>
#     <tr>
#       <td>3200</td>
#       <td>0.005400</td>
#     </tr>
#     <tr>
#       <td>3250</td>
#       <td>0.005700</td>
#     </tr>
#     <tr>
#       <td>3300</td>
#       <td>0.006200</td>
#     </tr>
#     <tr>
#       <td>3350</td>
#       <td>0.007200</td>
#     </tr>
#     <tr>
#       <td>3400</td>
#       <td>0.006300</td>
#     </tr>
#     <tr>
#       <td>3450</td>
#       <td>0.006600</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.007300</td>
#     </tr>
#     <tr>
#       <td>3550</td>
#       <td>0.007200</td>
#     </tr>
#     <tr>
#       <td>3600</td>
#       <td>0.006400</td>
#     </tr>
#     <tr>
#       <td>3650</td>
#       <td>0.006400</td>
#     </tr>
#     <tr>
#       <td>3700</td>
#       <td>0.006700</td>
#     </tr>
#     <tr>
#       <td>3750</td>
#       <td>0.007200</td>
#     </tr>
#     <tr>
#       <td>3800</td>
#       <td>0.006800</td>
#     </tr>
#     <tr>
#       <td>3850</td>
#       <td>0.007200</td>
#     </tr>
#     <tr>
#       <td>3900</td>
#       <td>0.006800</td>
#     </tr>
#     <tr>
#       <td>3950</td>
#       <td>0.007400</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.006400</td>
#     </tr>
#     <tr>
#       <td>4050</td>
#       <td>0.007700</td>
#     </tr>
#     <tr>
#       <td>4100</td>
#       <td>0.006700</td>
#     </tr>
#     <tr>
#       <td>4150</td>
#       <td>0.008000</td>
#     </tr>
#     <tr>
#       <td>4200</td>
#       <td>0.006700</td>
#     </tr>
#     <tr>
#       <td>4250</td>
#       <td>0.007700</td>
#     </tr>
#     <tr>
#       <td>4300</td>
#       <td>0.007400</td>
#     </tr>
#     <tr>
#       <td>4350</td>
#       <td>0.003600</td>
#     </tr>
#     <tr>
#       <td>4400</td>
#       <td>0.004000</td>
#     </tr>
#     <tr>
#       <td>4450</td>
#       <td>0.004200</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.004500</td>
#     </tr>
#     <tr>
#       <td>4550</td>
#       <td>0.004300</td>
#     </tr>
#     <tr>
#       <td>4600</td>
#       <td>0.003600</td>
#     </tr>
#     <tr>
#       <td>4650</td>
#       <td>0.004000</td>
#     </tr>
#     <tr>
#       <td>4700</td>
#       <td>0.003800</td>
#     </tr>
#     <tr>
#       <td>4750</td>
#       <td>0.004300</td>
#     </tr>
#     <tr>
#       <td>4800</td>
#       <td>0.004500</td>
#     </tr>
#     <tr>
#       <td>4850</td>
#       <td>0.004000</td>
#     </tr>
#     <tr>
#       <td>4900</td>
#       <td>0.004200</td>
#     </tr>
#     <tr>
#       <td>4950</td>
#       <td>0.004700</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.004400</td>
#     </tr>
#     <tr>
#       <td>5050</td>
#       <td>0.004100</td>
#     </tr>
#     <tr>
#       <td>5100</td>
#       <td>0.005500</td>
#     </tr>
#     <tr>
#       <td>5150</td>
#       <td>0.004300</td>
#     </tr>
#     <tr>
#       <td>5200</td>
#       <td>0.004600</td>
#     </tr>
#     <tr>
#       <td>5250</td>
#       <td>0.005200</td>
#     </tr>
#     <tr>
#       <td>5300</td>
#       <td>0.005200</td>
#     </tr>
#     <tr>
#       <td>5350</td>
#       <td>0.004100</td>
#     </tr>
#     <tr>
#       <td>5400</td>
#       <td>0.003700</td>
#     </tr>
#     <tr>
#       <td>5450</td>
#       <td>0.004700</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.004800</td>
#     </tr>
#     <tr>
#       <td>5550</td>
#       <td>0.004900</td>
#     </tr>
#     <tr>
#       <td>5600</td>
#       <td>0.004400</td>
#     </tr>
#     <tr>
#       <td>5650</td>
#       <td>0.004500</td>
#     </tr>
#     <tr>
#       <td>5700</td>
#       <td>0.004700</td>
#     </tr>
#     <tr>
#       <td>5750</td>
#       <td>0.003900</td>
#     </tr>
#     <tr>
#       <td>5800</td>
#       <td>0.002800</td>
#     </tr>
#     <tr>
#       <td>5850</td>
#       <td>0.002600</td>
#     </tr>
#     <tr>
#       <td>5900</td>
#       <td>0.002500</td>
#     </tr>
#     <tr>
#       <td>5950</td>
#       <td>0.003000</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.003200</td>
#     </tr>
#     <tr>
#       <td>6050</td>
#       <td>0.002700</td>
#     </tr>
#     <tr>
#       <td>6100</td>
#     <div>
#
#       <progress value='14330' max='14330' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [14330/14330 1:07:58, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>1.377500</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.022600</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.022400</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.022500</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.020400</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.020000</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.021700</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.019900</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.020200</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.021300</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.022300</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.023800</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>0.021000</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.021700</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>0.022000</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.023400</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>0.021500</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.021100</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>0.020400</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.022700</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>0.019800</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.019400</td>
#     </tr>
#     <tr>
#       <td>1150</td>
#       <td>0.019300</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.019900</td>
#     </tr>
#     <tr>
#       <td>1250</td>
#       <td>0.021900</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.020100</td>
#     </tr>
#     <tr>
#       <td>1350</td>
#       <td>0.017600</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.017700</td>
#     </tr>
#     <tr>
#       <td>1450</td>
#       <td>0.016900</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.010000</td>
#     </tr>
#     <tr>
#       <td>1550</td>
#       <td>0.012700</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.010300</td>
#     </tr>
#     <tr>
#       <td>1650</td>
#       <td>0.009600</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.010600</td>
#     </tr>
#     <tr>
#       <td>1750</td>
#       <td>0.010000</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.009900</td>
#     </tr>
#     <tr>
#       <td>1850</td>
#       <td>0.011100</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>0.009600</td>
#     </tr>
#     <tr>
#       <td>1950</td>
#       <td>0.011000</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.011900</td>
#     </tr>
#     <tr>
#       <td>2050</td>
#       <td>0.010100</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.010100</td>
#     </tr>
#     <tr>
#       <td>2150</td>
#       <td>0.010800</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>0.011500</td>
#     </tr>
#     <tr>
#       <td>2250</td>
#       <td>0.011300</td>
#     </tr>
#     <tr>
#       <td>2300</td>
#       <td>0.012200</td>
#     </tr>
#     <tr>
#       <td>2350</td>
#       <td>0.011200</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>0.011200</td>
#     </tr>
#     <tr>
#       <td>2450</td>
#       <td>0.011900</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.012500</td>
#     </tr>
#     <tr>
#       <td>2550</td>
#       <td>0.012100</td>
#     </tr>
#     <tr>
#       <td>2600</td>
#       <td>0.010900</td>
#     </tr>
#     <tr>
#       <td>2650</td>
#       <td>0.012200</td>
#     </tr>
#     <tr>
#       <td>2700</td>
#       <td>0.011100</td>
#     </tr>
#     <tr>
#       <td>2750</td>
#       <td>0.010600</td>
#     </tr>
#     <tr>
#       <td>2800</td>
#       <td>0.012900</td>
#     </tr>
#     <tr>
#       <td>2850</td>
#       <td>0.010500</td>
#     </tr>
#     <tr>
#       <td>2900</td>
#       <td>0.007400</td>
#     </tr>
#     <tr>
#       <td>2950</td>
#       <td>0.006700</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.007300</td>
#     </tr>
#     <tr>
#       <td>3050</td>
#       <td>0.007000</td>
#     </tr>
#     <tr>
#       <td>3100</td>
#       <td>0.005300</td>
#     </tr>
#     <tr>
#       <td>3150</td>
#       <td>0.005600</td>
#     </tr>
#     <tr>
#       <td>3200</td>
#       <td>0.005400</td>
#     </tr>
#     <tr>
#       <td>3250</td>
#       <td>0.005700</td>
#     </tr>
#     <tr>
#       <td>3300</td>
#       <td>0.006200</td>
#     </tr>
#     <tr>
#       <td>3350</td>
#       <td>0.007200</td>
#     </tr>
#     <tr>
#       <td>3400</td>
#       <td>0.006300</td>
#     </tr>
#     <tr>
#       <td>3450</td>
#       <td>0.006600</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.007300</td>
#     </tr>
#     <tr>
#       <td>3550</td>
#       <td>0.007200</td>
#     </tr>
#     <tr>
#       <td>3600</td>
#       <td>0.006400</td>
#     </tr>
#     <tr>
#       <td>3650</td>
#       <td>0.006400</td>
#     </tr>
#     <tr>
#       <td>3700</td>
#       <td>0.006700</td>
#     </tr>
#     <tr>
#       <td>3750</td>
#       <td>0.007200</td>
#     </tr>
#     <tr>
#       <td>3800</td>
#       <td>0.006800</td>
#     </tr>
#     <tr>
#       <td>3850</td>
#       <td>0.007200</td>
#     </tr>
#     <tr>
#       <td>3900</td>
#       <td>0.006800</td>
#     </tr>
#     <tr>
#       <td>3950</td>
#       <td>0.007400</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.006400</td>
#     </tr>
#     <tr>
#       <td>4050</td>
#       <td>0.007700</td>
#     </tr>
#     <tr>
#       <td>4100</td>
#       <td>0.006700</td>
#     </tr>
#     <tr>
#       <td>4150</td>
#       <td>0.008000</td>
#     </tr>
#     <tr>
#       <td>4200</td>
#       <td>0.006700</td>
#     </tr>
#     <tr>
#       <td>4250</td>
#       <td>0.007700</td>
#     </tr>
#     <tr>
#       <td>4300</td>
#       <td>0.007400</td>
#     </tr>
#     <tr>
#       <td>4350</td>
#       <td>0.003600</td>
#     </tr>
#     <tr>
#       <td>4400</td>
#       <td>0.004000</td>
#     </tr>
#     <tr>
#       <td>4450</td>
#       <td>0.004200</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.004500</td>
#     </tr>
#     <tr>
#       <td>4550</td>
#       <td>0.004300</td>
#     </tr>
#     <tr>
#       <td>4600</td>
#       <td>0.003600</td>
#     </tr>
#     <tr>
#       <td>4650</td>
#       <td>0.004000</td>
#     </tr>
#     <tr>
#       <td>4700</td>
#       <td>0.003800</td>
#     </tr>
#     <tr>
#       <td>4750</td>
#       <td>0.004300</td>
#     </tr>
#     <tr>
#       <td>4800</td>
#       <td>0.004500</td>
#     </tr>
#     <tr>
#       <td>4850</td>
#       <td>0.004000</td>
#     </tr>
#     <tr>
#       <td>4900</td>
#       <td>0.004200</td>
#     </tr>
#     <tr>
#       <td>4950</td>
#       <td>0.004700</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.004400</td>
#     </tr>
#     <tr>
#       <td>5050</td>
#       <td>0.004100</td>
#     </tr>
#     <tr>
#       <td>5100</td>
#       <td>0.005500</td>
#     </tr>
#     <tr>
#       <td>5150</td>
#       <td>0.004300</td>
#     </tr>
#     <tr>
#       <td>5200</td>
#       <td>0.004600</td>
#     </tr>
#     <tr>
#       <td>5250</td>
#       <td>0.005200</td>
#     </tr>
#     <tr>
#       <td>5300</td>
#       <td>0.005200</td>
#     </tr>
#     <tr>
#       <td>5350</td>
#       <td>0.004100</td>
#     </tr>
#     <tr>
#       <td>5400</td>
#       <td>0.003700</td>
#     </tr>
#     <tr>
#       <td>5450</td>
#       <td>0.004700</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.004800</td>
#     </tr>
#     <tr>
#       <td>5550</td>
#       <td>0.004900</td>
#     </tr>
#     <tr>
#       <td>5600</td>
#       <td>0.004400</td>
#     </tr>
#     <tr>
#       <td>5650</td>
#       <td>0.004500</td>
#     </tr>
#     <tr>
#       <td>5700</td>
#       <td>0.004700</td>
#     </tr>
#     <tr>
#       <td>5750</td>
#       <td>0.003900</td>
#     </tr>
#     <tr>
#       <td>5800</td>
#       <td>0.002800</td>
#     </tr>
#     <tr>
#       <td>5850</td>
#       <td>0.002600</td>
#     </tr>
#     <tr>
#       <td>5900</td>
#       <td>0.002500</td>
#     </tr>
#     <tr>
#       <td>5950</td>
#       <td>0.003000</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.003200</td>
#     </tr>
#     <tr>
#       <td>6050</td>
#       <td>0.002700</td>
#     </tr>
#     <tr>
#       <td>6100</td>
#       <td>0.003100</td>
# TrainOutput(global_step=14330, training_loss=0.009992766419564687, metrics={'train_runtime': 4079.604, 'train_samples_per_second': 21.063, 'train_steps_per_second': 3.513, 'total_flos': 5825772996526080.0, 'train_loss': 0.009992766419564687, 'epoch': 10.0})

# %%
# Evaluation (sample)
chrf_metric = evaluate.load("chrf")
bleu_metric= evaluate.load("bleu")

def evaluate_model(n_samples=5):
    references = []
    predictions = []

    count = 0
    for i in range(len(test_data)):
        if count >= n_samples:
            break

        source_text = test_data.iloc[i]["Arabic"]
        target_text = test_data.iloc[i]["English"]

        if not isinstance(source_text, str) or not source_text.strip():
            continue  # Skip blank or non-string inputs

        inputs = tokenizer(
            source_text,
            return_tensors="pt",
            padding=True,
            truncation=True,
            max_length=256,
        ).to(model.device)

        output_ids = model.generate(
            **inputs,
            max_length=128,
            num_beams=10,
            length_penalty=1.5,
            early_stopping=True
        )
        prediction = tokenizer.decode(output_ids[0], skip_special_tokens=True)

        print(f"Arabic:    {source_text}")
        print(f"Predicted: {prediction}")
        print(f"True:      {target_text}")
        print("-" * 80)

        references.append([target_text])
        predictions.append(prediction)
        count += 1

    if len(references) > 0 and len(predictions) > 0:
        chrf_score = chrf_metric.compute(predictions=predictions, references=references)
        bleu_score = bleu_metric.compute(predictions=predictions, references=references)
        print(f"ChrF Score: {chrf_score['score']}")
        print(f"bleu score: {bleu_score['bleu']}")
    else:
        print("No valid predictions to evaluate.")


evaluate_model()
# Out:
# Downloading builder script:   0%|          | 0.00/9.01k [00:00<?, ?B/s]
# Downloading builder script:   0%|          | 0.00/5.94k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/1.55k [00:00<?, ?B/s]
# Downloading extra modules:   0%|          | 0.00/3.34k [00:00<?, ?B/s]
# Arabic:    كان الجو حارا جدا عصر اليوم.
# Predicted: It was very hot this afternoon.
# True:      It was very hot this afternoon.
# --------------------------------------------------------------------------------
# Arabic:    هل ستكون في المنزل لتناول العشاء؟
# Predicted: Will you be home for dinner?
# True:      Will you be home for dinner?
# --------------------------------------------------------------------------------
# Arabic:    لا انصح بذلك.
# Predicted: I don't recommend it.
# True:      I don't recommend that.
# --------------------------------------------------------------------------------
# Arabic:    امي اكبر من ابي سنا.
# Predicted: My mother is older than my father.
# True:      Mom is older than Dad.
# --------------------------------------------------------------------------------
# Arabic:    اعجبت عمتي بنجاحي.
# Predicted: My aunt liked my success.
# True:      My aunt was pleased with my success.
# --------------------------------------------------------------------------------
# ChrF Score: 74.41488217406318
# bleu score: 0.6111102921060977

# %%
# Evaluation (all)
chrf_metric = evaluate.load("chrf")
bleu_metric = evaluate.load("bleu")

def evaluate_model():
    references = []
    predictions = []

    for i in range(len(test_data)):
        source_text = test_data.iloc[i]["Arabic"]
        target_text = test_data.iloc[i]["English"]

        if not isinstance(source_text, str) or not source_text.strip():
            continue  # Skip blank or non-string inputs

        inputs = tokenizer(
            source_text,
            return_tensors="pt",
            padding=True,
            truncation=True,
            max_length=128,
        ).to(model.device)

        output_ids = model.generate(
            **inputs,
            max_length=256,
            num_beams=10,
            length_penalty=1.5,
            early_stopping=True
        )
        prediction = tokenizer.decode(output_ids[0], skip_special_tokens=True)

        print(f"Arabic:    {source_text}")
        print(f"Predicted: {prediction}")
        print(f"True:      {target_text}")
        print("-" * 80)

        references.append([target_text])
        predictions.append(prediction)

    if len(references) > 0 and len(predictions) > 0:
        chrf_score = chrf_metric.compute(predictions=predictions, references=references)
        bleu_score = bleu_metric.compute(predictions=predictions, references=references)
        print(f"ChrF Score: {chrf_score['score']}")
        print(f"BLEU Score: {bleu_score['bleu']}")
    else:
        print("No valid predictions to evaluate.")


evaluate_model()
# Out:
# Streaming output truncated to the last 5000 lines.
# True:      My mother can't ride a bicycle.
# --------------------------------------------------------------------------------
# Arabic:    لقد استخدم راسه.
# Predicted: He used his head.
# True:      He used his head.
# --------------------------------------------------------------------------------
# Arabic:    معظم الناس يظنون اني مجنون.
# Predicted: Most people think I'm crazy.
# True:      Most people think I'm crazy.
# --------------------------------------------------------------------------------
# Arabic:    اشتري توم كاميرا رخيصه جدا.
# Predicted: Tom bought a really cheap camera.
# True:      Tom bought a very cheap camera.
# --------------------------------------------------------------------------------
# Arabic:    ظننتني ابليت حسنا.
# Predicted: I thought I had done well.
# True:      I thought I did pretty well.
# --------------------------------------------------------------------------------
# Arabic:    اكره القهوه.
# Predicted: I hate coffee.
# True:      I hate coffee.
# --------------------------------------------------------------------------------
# Arabic:    احب القصص المصوره.
# Predicted: I like movies.
# True:      I love comic books.
# --------------------------------------------------------------------------------
# Arabic:    اريد ان اتي ايضا
# Predicted: I want to come, too.
# True:      I want to come, too.
# --------------------------------------------------------------------------------
# Arabic:    هل يبدو لك باني امزح؟
# Predicted: Does it look like I'm joking?
# True:      Do I look like I'm kidding?
# --------------------------------------------------------------------------------
# Arabic:    لقد اتبعوك.
# Predicted: They followed you.
# True:      They followed you.
# --------------------------------------------------------------------------------
# Arabic:    ايمكنك ان تبحث عنها؟
# Predicted: Can you look for her?
# True:      Can you find it?
# --------------------------------------------------------------------------------
# Arabic:    لننتظر قليلا.
# Predicted: Let's wait a while.
# True:      Let's wait a while.
# --------------------------------------------------------------------------------
# Arabic:    لم نرك منذ اربع سنين.
# Predicted: We haven't seen you for four years.
# True:      We haven't seen you in the past four years.
# --------------------------------------------------------------------------------
# Arabic:    اتحبينني بحق؟
# Predicted: Do you really love me?
# True:      Do you really love me?
# --------------------------------------------------------------------------------
# Arabic:    كم انت محظوظه!
# Predicted: How lucky you are!
# True:      How lucky you are!
# --------------------------------------------------------------------------------
# Arabic:    هل ترغب في الرقص معي؟
# Predicted: Would you like to dance with me?
# True:      Would you like to dance with me?
# --------------------------------------------------------------------------------
# Arabic:    ماذا تريد ان تاكل؟
# Predicted: What would you like to eat?
# True:      What do you want to eat?
# --------------------------------------------------------------------------------
# Arabic:    ذاك البيت له.
# Predicted: That house belongs to him.
# True:      That house belongs to him.
# --------------------------------------------------------------------------------
# Arabic:    هذه كتبي.
# Predicted: These books belong to me.
# True:      These are my books.
# --------------------------------------------------------------------------------
# Arabic:    لم يعرف توم كم واحدا منهم احتاج الي مساعده
# Predicted: Tom didn't know how many people needed help.
# True:      Tom didn't know how many of them needed help.
# --------------------------------------------------------------------------------
# Arabic:    نحن رجال.
# Predicted: We are men.
# True:      We are men.
# --------------------------------------------------------------------------------
# Arabic:    خسر وظيفته.
# Predicted: He lost his job.
# True:      He lost his job.
# --------------------------------------------------------------------------------
# Arabic:    انها حاده الذكاء.
# Predicted: She is sharp and clever.
# True:      She is very intelligent.
# --------------------------------------------------------------------------------
# Arabic:    الانجليزيه لغه سهله التعلم.
# Predicted: English is an easy language to learn.
# True:      English is easy to learn.
# --------------------------------------------------------------------------------
# Arabic:    انا لست نادما علي مجييي هنا.
# Predicted: I don't regret coming here.
# True:      I don't regret coming here.
# --------------------------------------------------------------------------------
# Arabic:    انا هنا منذ الساعه الخامسه.
# Predicted: I have been here since five o'clock.
# True:      I have been here since five o'clock.
# --------------------------------------------------------------------------------
# Arabic:    كل شيء يحدث لسبب ما.
# Predicted: Everything happens for a reason.
# True:      Everything happens for a reason.
# --------------------------------------------------------------------------------
# Arabic:    من الافضل ان تذهب.
# Predicted: You had better go.
# True:      You should go.
# --------------------------------------------------------------------------------
# Arabic:    انا احب الحيوانات علي سبيل المثال القطط والكلاب.
# Predicted: I like animals, for example, cats and dogs.
# True:      I like animals, for example, cats and dogs.
# --------------------------------------------------------------------------------
# Arabic:    لا مشكله!
# Predicted: No problem!
# True:      No problem!
# --------------------------------------------------------------------------------
# Arabic:    تبدو متعبا.
# Predicted: You look tired.
# True:      You look tired.
# --------------------------------------------------------------------------------
# Arabic:    يشبه اباه.
# Predicted: He resembles his father.
# True:      He looks like his father.
# --------------------------------------------------------------------------------
# Arabic:    كيف الاحوال في سوق السمك؟
# Predicted: How are the conditions in the fish market?
# True:      How is it going in the fish market?
# --------------------------------------------------------------------------------
# Arabic:    هذا مستحيل.
# Predicted: It's impossible.
# True:      It's impossible.
# --------------------------------------------------------------------------------
# Arabic:    فاز فريق مانتشستر يونايتد باربعه اهداف مقابل اثنين.
# Predicted: The manchesterist team won four defeats for two.
# True:      Manchester United won the match, four to two.
# --------------------------------------------------------------------------------
# Arabic:    ما اجمل هذه الزهره!
# Predicted: What a beautiful flower!
# True:      How beautiful this flower is!
# --------------------------------------------------------------------------------
# Arabic:    توقف والا ساسحب السياره اكثر.
# Predicted: Stop, or I'll pull the car.
# True:      Stop or I'll pull the car over!
# --------------------------------------------------------------------------------
# Arabic:    لا يمكن ان يكون ذلك صحيحا.
# Predicted: That cannot be true.
# True:      It can't be true.
# --------------------------------------------------------------------------------
# Arabic:    انا جاهز تقريبا.
# Predicted: I'm almost ready.
# True:      I'm about ready.
# --------------------------------------------------------------------------------
# Arabic:    هو سعيد
# Predicted: He is happy.
# True:      He is happy.
# --------------------------------------------------------------------------------
# Arabic:    انا انتظر ردك.
# Predicted: I was waiting for your reply.
# True:      I'm waiting for your reply.
# --------------------------------------------------------------------------------
# Arabic:    انهم في نفس العمر تقريبا.
# Predicted: They are about the same age.
# True:      They are about the same age.
# --------------------------------------------------------------------------------
# Arabic:    اصابه الصلع في شبابه.
# Predicted: He hurt a baldness as a child.
# True:      He started going bald quite young.
# --------------------------------------------------------------------------------
# Arabic:    بامكانك المذاكره هنا.
# Predicted: You can study here.
# True:      You can study here.
# --------------------------------------------------------------------------------
# Arabic:    يجب عليك ان تقلل من الاطعمه الدسمه التي تاكلها.
# Predicted: You should cut down on the hard food you're eating.
# True:      You should cut down on the amount of fattening food that you eat.
# --------------------------------------------------------------------------------
# Arabic:    كم تبعد الحديقه عن منزلك؟
# Predicted: How far is the garden from your house?
# True:      How far is it from your house to the park?
# --------------------------------------------------------------------------------
# Arabic:    عثرت عل توم يدخن النرجيله.
# Predicted: I found Tom smoking a squirt.
# True:      I found Tom smoking a hookah.
# --------------------------------------------------------------------------------
# Arabic:    ان توم شديد.
# Predicted: Tom is strong.
# True:      Tom's strict.
# --------------------------------------------------------------------------------
# Arabic:    انا لا الومه.
# Predicted: I don't blame him.
# True:      I don't blame him.
# --------------------------------------------------------------------------------
# Arabic:    حان وقت طعام الغداء.
# Predicted: It's lunch time.
# True:      It's lunch time.
# --------------------------------------------------------------------------------
# Arabic:    لم تدرك خطاها.
# Predicted: She didn't realize her mistake.
# True:      She was unconscious of her mistake.
# --------------------------------------------------------------------------------
# Arabic:    سيتم الامر
# Predicted: It'll be done.
# True:      It'll turn up.
# --------------------------------------------------------------------------------
# Arabic:    اسكن في هذا الفندق.
# Predicted: I stay in this hotel.
# True:      I live in this hotel.
# --------------------------------------------------------------------------------
# Arabic:    لاشيء يحدث بين ليله وضحاها.
# Predicted: Nothing happens overnight.
# True:      Nothing happens overnight.
# --------------------------------------------------------------------------------
# Arabic:    هل تحب الجري؟
# Predicted: Do you like running?
# True:      Do you like to run?
# --------------------------------------------------------------------------------
# Arabic:    احب دراسه التاريخ.
# Predicted: I like studying history.
# True:      I like studying history.
# --------------------------------------------------------------------------------
# Arabic:    ويستطيع الجميع المساهمه.
# Predicted: Everyone is able to contribute.
# True:      And everyone has the ability to contribute.
# --------------------------------------------------------------------------------
# Arabic:    عليك ان تساعد والدتك.
# Predicted: You must help your mother.
# True:      You must help your mother.
# --------------------------------------------------------------------------------
# Arabic:    فضلا، ايمكنني الحصول علي كوب قهوه اخر؟
# Predicted: Could I have another cup of coffee?
# True:      Could I have one more coffee, please?
# --------------------------------------------------------------------------------
# Arabic:    ما الامر؟
# Predicted: What gives?
# True:      What's the matter?
# --------------------------------------------------------------------------------
# Arabic:    لدي ثلاث كاميرات.
# Predicted: I have three cams.
# True:      I have three cameras.
# --------------------------------------------------------------------------------
# Arabic:    تمتعنا بالسباحه في النهر.
# Predicted: We enjoyed swimming in the river.
# True:      We enjoyed swimming in the river.
# --------------------------------------------------------------------------------
# Arabic:    توم قتل في حادث.
# Predicted: Tom was killed in an accident.
# True:      Tom was killed in an accident.
# --------------------------------------------------------------------------------
# Arabic:    انا لم افهم.
# Predicted: I didn't understand.
# True:      I do not understand.
# --------------------------------------------------------------------------------
# Arabic:    وزع علينا الورق.
# Predicted: He divided the cards for us.
# True:      Deal us the cards.
# --------------------------------------------------------------------------------
# Arabic:    ليس ذلك منطقيا بتاتا.
# Predicted: That doesn't make any sense.
# True:      That doesn't even make sense.
# --------------------------------------------------------------------------------
# Arabic:    ان كان لديك ما تقول، فقله.
# Predicted: If you have something to say, say it.
# True:      If you've got something to say, just say it.
# --------------------------------------------------------------------------------
# Arabic:    حكم علي المتهم بالاعدام.
# Predicted: The accused was sentenced to death.
# True:      The accused was sentenced to death.
# --------------------------------------------------------------------------------
# Arabic:    تقاعدت السنه الماضيه.
# Predicted: I retired last year.
# True:      I retired last year.
# --------------------------------------------------------------------------------
# Arabic:    احذر!
# Predicted: Take care!
# True:      Look out!
# --------------------------------------------------------------------------------
# Arabic:    اسرع و الا تاخرت.
# Predicted: Hurry up, or you'll be late.
# True:      Hurry up, or you will be late.
# --------------------------------------------------------------------------------
# Arabic:    كان الانجذاب متبادلا.
# Predicted: The attraction was reciprocated.
# True:      The attraction was mutual.
# --------------------------------------------------------------------------------
# Arabic:    نحن لا نعلم من هي.
# Predicted: We don't know who she is.
# True:      We don't know her.
# --------------------------------------------------------------------------------
# Arabic:    نحن نعرفه
# Predicted: We know him.
# True:      We know him.
# --------------------------------------------------------------------------------
# Arabic:    ساطلق عليه الرصاص.
# Predicted: I'll shoot him.
# True:      I will shoot him.
# --------------------------------------------------------------------------------
# Arabic:    يصبح الجو ابرد يوما بعد يوم.
# Predicted: It is getting cold day by day.
# True:      It is getting colder day by day.
# --------------------------------------------------------------------------------
# Arabic:    لم يفاجيني ذلك.
# Predicted: That didn't surprise me.
# True:      It doesn't surprise me.
# --------------------------------------------------------------------------------
# Arabic:    انا لم ار شييا مثل هذا.
# Predicted: I've never seen anything like that.
# True:      I've never seen anything like that.
# --------------------------------------------------------------------------------
# Arabic:    الحب و الكره شعوران متعاكسان
# Predicted: Love and soccer are opposite feelings.
# True:      Love and hate are opposite emotions.
# --------------------------------------------------------------------------------
# Arabic:    سياخذ هذا وقتا طويلا.
# Predicted: This will take a long time.
# True:      This will take a lot of time.
# --------------------------------------------------------------------------------
# Arabic:    سال السايح بخصوص المكوث لهذه الليله .
# Predicted: The tourist asked about staying tonight.
# True:      The tourist asked for lodging for the night.
# --------------------------------------------------------------------------------
# Arabic:    هل حقا انت اميره ؟
# Predicted: Are you really a woman?
# True:      Are you really a princess?
# --------------------------------------------------------------------------------
# Arabic:    انه يتحدث علي الهاتف.
# Predicted: He is talking on the phone.
# True:      He's talking on the telephone.
# --------------------------------------------------------------------------------
# Arabic:    ماذا ستفعل في عطله نهايه الاسبوع؟
# Predicted: What are you going to do this weekend?
# True:      What'll you be doing over the weekend?
# --------------------------------------------------------------------------------
# Arabic:    اكتملت المرحله الاولي.
# Predicted: The first phase has been complete.
# True:      The first stage is complete.
# --------------------------------------------------------------------------------
# Arabic:    انا لست في وضع يسمح بان اقبلها.
# Predicted: I'm not in a position to accept her.
# True:      I'm not in a position to accept it.
# --------------------------------------------------------------------------------
# Arabic:    تفاجات زوجتي.
# Predicted: My wife is surprised.
# True:      My wife looked surprised.
# --------------------------------------------------------------------------------
# Arabic:    هل تعلم من انا ؟
# Predicted: Do you know who I am?
# True:      Do you know who I am?
# --------------------------------------------------------------------------------
# Arabic:    الغايه تبرر الوسيله.
# Predicted: The intent is to explain the method.
# True:      The end justifies the means.
# --------------------------------------------------------------------------------
# Arabic:    انا لا اخرق القانون.
# Predicted: I'm not breaking the law.
# True:      I'm not breaking the law.
# --------------------------------------------------------------------------------
# Arabic:    يقول توم بانه ليس هو من كسر النافذه
# Predicted: Tom says that he's not the one who broke the window.
# True:      Tom says that he wasn't the one who broke the window.
# --------------------------------------------------------------------------------
# Arabic:    يمكننا ان نوصله الليله.
# Predicted: We can make it tonight.
# True:      We can deliver it this evening.
# --------------------------------------------------------------------------------
# Arabic:    تعال معنا.
# Predicted: Come with us.
# True:      Come along.
# --------------------------------------------------------------------------------
# Arabic:    هل انت جاهز للذهاب للبيت الان؟
# Predicted: Are you ready to go home now?
# True:      Are you ready to go home now?
# --------------------------------------------------------------------------------
# Arabic:    وضح لي ما تريدني ان افعل.
# Predicted: He showed me what you wanted me to do.
# True:      Tell me what you want me to do.
# --------------------------------------------------------------------------------
# Arabic:    هل صاحبك يحب الشاي؟
# Predicted: Does your friend like tea?
# True:      Does your friend like tea?
# --------------------------------------------------------------------------------
# Arabic:    طلب منا ان نساعده.
# Predicted: He asked us to help him.
# True:      He asked us to help him.
# --------------------------------------------------------------------------------
# Arabic:    يبدو ان بعض الاناس يتفقون معك.
# Predicted: It appears that some people agree with you.
# True:      Some people seem to agree with you.
# --------------------------------------------------------------------------------
# Arabic:    هل ستمطر اليوم؟
# Predicted: Will it rain today?
# True:      Will it rain today?
# --------------------------------------------------------------------------------
# Arabic:    ان التحدث بالانجليزيه امر ممتع.
# Predicted: Speaking English is a lot of fun.
# True:      It's fun to speak in English.
# --------------------------------------------------------------------------------
# Arabic:    انا اخذته الي المستشفي.
# Predicted: I took him to the hospital.
# True:      I took him to the hospital.
# --------------------------------------------------------------------------------
# Arabic:    لقد قرات الكتاب
# Predicted: I read the book.
# True:      I have read the book.
# --------------------------------------------------------------------------------
# Arabic:    اشتريت سياره رياضيه حمراء.
# Predicted: I bought a red sports car.
# True:      I bought a red sports car.
# --------------------------------------------------------------------------------
# Arabic:    لم لا تجلس و تستريح؟
# Predicted: Why don't you sit down and relax?
# True:      Why don't you sit down and relax?
# --------------------------------------------------------------------------------
# Arabic:    يظهر من شكل السماء ان الثلج سيتساقط.
# Predicted: It appears from the look of the sky that the snow will fall.
# True:      Judging from the look of the sky, it is going to snow.
# --------------------------------------------------------------------------------
# Arabic:    نريد السلام في العالم.
# Predicted: We want peace in the world.
# True:      We want peace in the world.
# --------------------------------------------------------------------------------
# Arabic:    الدرس الاول سهل.
# Predicted: The first lesson is easy.
# True:      The first lesson is easy.
# --------------------------------------------------------------------------------
# Arabic:    هذا حقا لطفا منك.
# Predicted: That's really sweet of you.
# True:      It is really nice of you.
# --------------------------------------------------------------------------------
# Arabic:    لم اكن اقصد احباطها.
# Predicted: I didn't mean to disappoint her.
# True:      I did not mean to disappoint her.
# --------------------------------------------------------------------------------
# Arabic:    اتبع قلبك فحسب.
# Predicted: Just follow your heart.
# True:      Just follow your heart.
# --------------------------------------------------------------------------------
# Arabic:    اوتظنني سادعك تفعل ذلك؟
# Predicted: Do you think I'll let you do that?
# True:      Do you really think that I'm going to let you do that?
# --------------------------------------------------------------------------------
# Arabic:    انا حقا اثق بقدرته.
# Predicted: I really trust his ability.
# True:      I really trust his ability.
# --------------------------------------------------------------------------------
# Arabic:    هل تفهمني؟
# Predicted: Do you understand me?
# True:      Do you understand me?
# --------------------------------------------------------------------------------
# Arabic:    لم يكن علي فعل شيء.
# Predicted: I shouldn't have done anything.
# True:      I didn't have to do anything.
# --------------------------------------------------------------------------------
# Arabic:    اظن ان توم علي حق.
# Predicted: I think Tom is right.
# True:      I think Tom is right.
# --------------------------------------------------------------------------------
# Arabic:    انا سعيد جدا لاني لم اكن هناك.
# Predicted: I'm very happy that I wasn't there.
# True:      I'm very glad I wasn't there.
# --------------------------------------------------------------------------------
# Arabic:    هل انت مبسوط هنا؟
# Predicted: Are you prepped here?
# True:      Are you happy here?
# --------------------------------------------------------------------------------
# Arabic:    ليست قلقه بشان درجات اختبارها البته.
# Predicted: She isn't worried about her examination degrees.
# True:      She is not in the least worried about her test scores.
# --------------------------------------------------------------------------------
# Arabic:    انت المخطا في الحادث.
# Predicted: You are wrong in the matter.
# True:      You are to blame for the accident.
# --------------------------------------------------------------------------------
# Arabic:    كان عليك ان تكون قد بدات الان.
# Predicted: You should have started now.
# True:      You should have started by now.
# --------------------------------------------------------------------------------
# Arabic:    لماذا لم تستطع القدوم بالامس؟
# Predicted: Why couldn't you come yesterday?
# True:      Why couldn't you come yesterday?
# --------------------------------------------------------------------------------
# Arabic:    امل ان هذه معلومات ذات مصداقيه.
# Predicted: I hope this is information that is correct.
# True:      I hope this is accurate information.
# --------------------------------------------------------------------------------
# Arabic:    توم اخبرني بان لا ادخل المغاره.
# Predicted: Tom told me not to insert the guitar.
# True:      Tom told me not to go into the cave.
# --------------------------------------------------------------------------------
# Arabic:    وقفت سياره متعطله في منتصف الطريق.
# Predicted: She parked in the middle of a car.
# True:      A broken-down car was standing in the middle of the road.
# --------------------------------------------------------------------------------
# Arabic:    توم لم يكن ليعرف الفرق.
# Predicted: Tom didn't know the difference.
# True:      Tom wouldn't have known the difference.
# --------------------------------------------------------------------------------
# Arabic:    هل لديه كتب كثيره؟
# Predicted: Does he have many books?
# True:      Does he have many books?
# --------------------------------------------------------------------------------
# Arabic:    لم يرفع الستار حتي الان.
# Predicted: He hasn't raised the dart yet.
# True:      The curtain has not yet risen.
# --------------------------------------------------------------------------------
# Arabic:    تحلق الطيور.
# Predicted: The birds fly.
# True:      Birds fly.
# --------------------------------------------------------------------------------
# Arabic:    هل صعد كل الركاب؟
# Predicted: Did all the passengers go up?
# True:      Are all the passengers aboard?
# --------------------------------------------------------------------------------
# Arabic:    لناكل بطيخا!
# Predicted: Let's eat watermelon!
# True:      Let's have some watermelon.
# --------------------------------------------------------------------------------
# Arabic:    هو ترك توم يذهب.
# Predicted: He let Tom go.
# True:      He let Tom go.
# --------------------------------------------------------------------------------
# Arabic:    هل تركت اكراميه؟
# Predicted: Did you leave his tip?
# True:      Did you leave a tip?
# --------------------------------------------------------------------------------
# Arabic:    انا نرويجي.
# Predicted: I'm a Norwegian.
# True:      I am from Norway.
# --------------------------------------------------------------------------------
# Arabic:    هل يمكنك ان تخبرني كيف اصل الي المحطه؟
# Predicted: Could you tell me how to get to the station?
# True:      Can you tell me how to get to the station?
# --------------------------------------------------------------------------------
# Arabic:    هذه كتبي، وتلك كتبه.
# Predicted: These books are mine, and those books are his.
# True:      These are my books, and those are his books.
# --------------------------------------------------------------------------------
# Arabic:    فحصوا مدي نقاوه الماء.
# Predicted: They examined the length of the water.
# True:      They checked how pure the water was.
# --------------------------------------------------------------------------------
# Arabic:    عشنا في اوساكا ست سنوات.
# Predicted: We have lived in Osaka for six years.
# True:      We have lived in Osaka six years.
# --------------------------------------------------------------------------------
# Arabic:    لماذا السياح الصينيون فظين لدرجه ؟
# Predicted: Why are the Chinese tourists so rude?
# True:      Why are Chinese tourists so rude?
# --------------------------------------------------------------------------------
# Arabic:    ايمكنني اخذ قسط من الراحه الان؟
# Predicted: Can I get some sleep now?
# True:      Can I take a break now?
# --------------------------------------------------------------------------------
# Arabic:    اذا كنت مكانك لفعلت نفس الشيء.
# Predicted: If I were you, I would also do the same.
# True:      If I were in your situation, I would do the same thing.
# --------------------------------------------------------------------------------
# Arabic:    انه لا يسكن في حيي.
# Predicted: He doesn't live in my neighborhood.
# True:      He doesn't live in my neighborhood.
# --------------------------------------------------------------------------------
# Arabic:    اصطاد الولد الطاير بالشبكه.
# Predicted: The fly boy caught by the web.
# True:      The boy captured the bird with a net.
# --------------------------------------------------------------------------------
# Arabic:    متي تخرج توم من الكليه؟
# Predicted: When does Tom get out of college?
# True:      When did Tom graduate from college?
# --------------------------------------------------------------------------------
# Arabic:    قل الحقيقه دايما.
# Predicted: Always tell the truth.
# True:      Always tell the truth.
# --------------------------------------------------------------------------------
# Arabic:    قيل ان هذا المنزل مسكون بالاشباح.
# Predicted: The house is said to be haunted.
# True:      The house is said to be haunted.
# --------------------------------------------------------------------------------
# Arabic:    ليست معك حيوانات او نباتات، صحيح؟
# Predicted: You don't have animals or plants, do you?
# True:      You don't have any plants or animals, right?
# --------------------------------------------------------------------------------
# Arabic:    لقد كنت مدرسا لمده عامين.
# Predicted: I've been a teacher for two years.
# True:      I've been a teacher for two years.
# --------------------------------------------------------------------------------
# Arabic:    انجزت واجباتي مبكرا اليوم.
# Predicted: I've done my homework earlier today.
# True:      Today, I was done with my homework early.
# --------------------------------------------------------------------------------
# Arabic:    كيف تقول وداعا باللغه الالمانيه؟
# Predicted: How do you say goodbye in German?
# True:      How do you say "good bye" in German?
# --------------------------------------------------------------------------------
# Arabic:    هذه المدينه تعجبني جدا.
# Predicted: This city I like very much.
# True:      I like this city very much.
# --------------------------------------------------------------------------------
# Arabic:    فقد الرجل الامل كليا.
# Predicted: The man lost all hope.
# True:      The man lost all hope.
# --------------------------------------------------------------------------------
# Arabic:    لا بد ان لهذا معني.
# Predicted: This must have meaning.
# True:      This has got to mean something.
# --------------------------------------------------------------------------------
# Arabic:    توم افتح الصنبور
# Predicted: Tom turned the faucet on.
# True:      Tom turned on the faucet.
# --------------------------------------------------------------------------------
# Arabic:    هذه التفاحه شديده الحمره.
# Predicted: This apple is very red.
# True:      This apple is very red.
# --------------------------------------------------------------------------------
# Arabic:    اثلجت بشده الامس.
# Predicted: It snowed hard yesterday.
# True:      It snowed hard yesterday.
# --------------------------------------------------------------------------------
# Arabic:    تعال الي الداخل
# Predicted: Come inside.
# True:      Come in.
# --------------------------------------------------------------------------------
# Arabic:    الناس يحبون الحريه.
# Predicted: People like freedom.
# True:      People love freedom.
# --------------------------------------------------------------------------------
# Arabic:    انا اعلم اين تسكن
# Predicted: I know where you live.
# True:      I know where you live.
# --------------------------------------------------------------------------------
# Arabic:    اتيت هنا املا رويه توم.
# Predicted: I came here to see Tom.
# True:      I came here hoping to see Tom.
# --------------------------------------------------------------------------------
# Arabic:    ما ان وصل الي المطار حتي اتصل بمكتبه.
# Predicted: As soon as he got to the airport, I called his office.
# True:      As soon as he arrived at the airport, he phoned his office.
# --------------------------------------------------------------------------------
# Arabic:    لم اتسلق جبل فوجي ابدا.
# Predicted: I've never climbed Mt. Fuji.
# True:      I've never climbed Mt. Fuji.
# --------------------------------------------------------------------------------
# Arabic:    اريد ان اتخرج الربيع القادم.
# Predicted: I want to graduate next spring.
# True:      Next spring I want to graduate.
# --------------------------------------------------------------------------------
# Arabic:    الن تذهب؟
# Predicted: Aren't you going?
# True:      Won't you go?
# --------------------------------------------------------------------------------
# Arabic:    لدي الكثير من الاصدقاء.
# Predicted: I have a lot of friends.
# True:      I have many friends.
# --------------------------------------------------------------------------------
# Arabic:    هذا دفتري.
# Predicted: This is my notebook.
# True:      This is my notebook.
# --------------------------------------------------------------------------------
# Arabic:    سيساعدني توم في تنظيف غرفتي
# Predicted: Tom will help me clean my room.
# True:      Tom will help me clean my room.
# --------------------------------------------------------------------------------
# Arabic:    امليها.
# Predicted: fill it out.
# True:      Fill it up.
# --------------------------------------------------------------------------------
# Arabic:    انت رجل صبور.
# Predicted: You are a patient man.
# True:      You're a patient man.
# --------------------------------------------------------------------------------
# Arabic:    لا اعرف ان كنا نحتاج ذلك.
# Predicted: I don't know if we need that.
# True:      I don't know if we needed that.
# --------------------------------------------------------------------------------
# Arabic:    اهدا.
# Predicted: Calm down.
# True:      Calm down.
# --------------------------------------------------------------------------------
# Arabic:    انت جلبت العار علي عايلتنا.
# Predicted: You brought Shame on our family.
# True:      You have brought shame upon our family.
# --------------------------------------------------------------------------------
# Arabic:    اتصلت بصديقي بعد ان وصلت الي المحطه.
# Predicted: I called my friend after I got to the station.
# True:      I called my friend after arriving at the station.
# --------------------------------------------------------------------------------
# Arabic:    الي ماذا تنظر؟
# Predicted: What are you looking at?
# True:      What are you looking at?
# --------------------------------------------------------------------------------
# Arabic:    تعمد ان يدوس علي قدمي.
# Predicted: He intentionally stepped on my foot.
# True:      He stepped on my foot on purpose.
# --------------------------------------------------------------------------------
# Arabic:    ارتكب توم خطا شنيعا.
# Predicted: Tom made a terrible mistake.
# True:      Tom made a big mistake.
# --------------------------------------------------------------------------------
# Arabic:    ظل الباب مغلقا.
# Predicted: The door remained closed.
# True:      The front door remained locked.
# --------------------------------------------------------------------------------
# Arabic:    عليك ان تتحمل الالم.
# Predicted: You must bear the pain.
# True:      You must endure the pain.
# --------------------------------------------------------------------------------
# Arabic:    من اجل ذلك فقد عمله.
# Predicted: For that reason, he lost his job.
# True:      For that reason, he lost his job.
# --------------------------------------------------------------------------------
# Arabic:    دعنا نذهب لنري اذا كان توم يستطيع ان يساعدنا.
# Predicted: Let's go see if Tom can help us.
# True:      Let's go see if Tom can help us.
# --------------------------------------------------------------------------------
# Arabic:    لدي اسبوع لانهي واجبي.
# Predicted: I have a week to finish my homework.
# True:      I have a week to do my homework.
# --------------------------------------------------------------------------------
# Arabic:    هل هناك مصعد؟
# Predicted: Is there an elevator?
# True:      Is there an elevator?
# --------------------------------------------------------------------------------
# Arabic:    كوني جاده ارجوك.
# Predicted: Please be serious.
# True:      Please be serious.
# --------------------------------------------------------------------------------
# Arabic:    لم سنرغب بعمل ذلك؟
# Predicted: Why would we want to do that?
# True:      Why would we want to do that?
# --------------------------------------------------------------------------------
# Arabic:    انت نعم الطالب.
# Predicted: You are the student.
# True:      You are a good student.
# --------------------------------------------------------------------------------
# Arabic:    عليك ان تعترف بفشلك.
# Predicted: You must admit your failure.
# True:      You should acknowledge your failure.
# --------------------------------------------------------------------------------
# Arabic:    يلعب توم وماري كره المضرب.
# Predicted: Tom and Mary play tennis.
# True:      Tom and Mary are playing tennis.
# --------------------------------------------------------------------------------
# Arabic:    هذه الهديه لك.
# Predicted: This gift is yours.
# True:      This is a present for you.
# --------------------------------------------------------------------------------
# Arabic:    انها تحب القراءه.
# Predicted: She loves reading.
# True:      She likes to read.
# --------------------------------------------------------------------------------
# Arabic:    لم لا يمكنك المجيء؟
# Predicted: Why can't you come?
# True:      Why can't you come?
# --------------------------------------------------------------------------------
# Arabic:    كل قطه لها شخصيتها المستقله.
# Predicted: Every cat has its own personality.
# True:      Each cat has its own personality.
# --------------------------------------------------------------------------------
# Arabic:    هذه الكتب جديده
# Predicted: These books are new.
# True:      These books are new.
# --------------------------------------------------------------------------------
# Arabic:    هذا هو الخيار الوحيد.
# Predicted: This is the only choice.
# True:      This is the only alternative.
# --------------------------------------------------------------------------------
# Arabic:    لا اريد ان اعمل.
# Predicted: I don't want to work.
# True:      I don't want to work.
# --------------------------------------------------------------------------------
# Arabic:    ابق معنا.
# Predicted: Stay with us.
# True:      Stay here with us.
# --------------------------------------------------------------------------------
# Arabic:    لا تظن ان توم سيتصل بك مجددا، اليس كذلك؟
# Predicted: You don't think Tom will call you again, do you?
# True:      You don't think Tom will call again, do you?
# --------------------------------------------------------------------------------
# Arabic:    هل انت وحدك؟
# Predicted: Are you alone?
# True:      Are you alone?
# --------------------------------------------------------------------------------
# Arabic:    قابلت توم في المكتبه يوم الاثنين.
# Predicted: I met Tom at the library on Monday.
# True:      I met Tom in the library on Monday.
# --------------------------------------------------------------------------------
# Arabic:    دعونا نخرج من هنا قبل ان يرانا توم.
# Predicted: Let's get out of here before Tom sees us.
# True:      Let's get out of here before Tom sees us.
# --------------------------------------------------------------------------------
# Arabic:    انا في الشهر الرابع من حملي.
# Predicted: I am four months pregnant.
# True:      I am four months pregnant.
# --------------------------------------------------------------------------------
# Arabic:    لا تقلق بشان ذلك.
# Predicted: Don't worry about it.
# True:      Don't worry about it.
# --------------------------------------------------------------------------------
# Arabic:    من الافضل ان تعيد كتابه هذه الجمله.
# Predicted: You'd better rewrote this sentence.
# True:      You should rewrite this sentence.
# --------------------------------------------------------------------------------
# Arabic:    شكرا علي جهودك.
# Predicted: Thank you for your efforts.
# True:      Thanks for the effort.
# --------------------------------------------------------------------------------
# Arabic:    يجني زوجي مايه الف دولار سنويا.
# Predicted: My husband makes one thousand dollars a year.
# True:      My husband makes a hundred thousand dollars a year.
# --------------------------------------------------------------------------------
# Arabic:    هل تعتقد ان توم سياتي؟
# Predicted: Do you think Tom will come?
# True:      Do you think Tom will come?
# --------------------------------------------------------------------------------
# Arabic:    انك متعب ، اليس كذلك؟
# Predicted: You are tired, aren't you?
# True:      You are tired, aren't you?
# --------------------------------------------------------------------------------
# Arabic:    الكل يريد ان يتعرف عليك. انك مشهور!
# Predicted: Everybody wants to know you. You are famous.
# True:      Everyone wants to meet you. You're famous!
# --------------------------------------------------------------------------------
# Arabic:    يجب ان تتوقف
# Predicted: You have to stop.
# True:      You have to stop.
# --------------------------------------------------------------------------------
# Arabic:    ليس عندي وقت.
# Predicted: I have no time.
# True:      I don't have time.
# --------------------------------------------------------------------------------
# Arabic:    انا واحد من طلابك
# Predicted: I'm one of your students.
# True:      I'm one of your students.
# --------------------------------------------------------------------------------
# Arabic:    انها بارده كالثلج.
# Predicted: It's as cold as ice.
# True:      It's as cold as ice.
# --------------------------------------------------------------------------------
# Arabic:    انهم يكرهونك.
# Predicted: They hate you.
# True:      They hate you.
# --------------------------------------------------------------------------------
# Arabic:    انا اتتطلع لحفله عيد القديسيين خاصتك.
# Predicted: I'm looking forward to your Mother's Day party.
# True:      I'm looking forward to your Halloween party.
# --------------------------------------------------------------------------------
# Arabic:    اننا جايعون.
# Predicted: We're hungry.
# True:      We are hungry.
# --------------------------------------------------------------------------------
# Arabic:    نحن اتون
# Predicted: We are coming.
# True:      We are coming.
# --------------------------------------------------------------------------------
# Arabic:    انه معتاد علي السفر.
# Predicted: He's used to traveling.
# True:      He's accustomed to traveling.
# --------------------------------------------------------------------------------
# Arabic:    انها بنفس طولك تقريبا.
# Predicted: She is almost as tall as you.
# True:      She is almost as tall as you.
# --------------------------------------------------------------------------------
# Arabic:    ابق بعيدا عني.
# Predicted: Stay away from me.
# True:      Keep away from me.
# --------------------------------------------------------------------------------
# Arabic:    رايع!
# Predicted: Awesome!
# True:      Terrific!
# --------------------------------------------------------------------------------
# Arabic:    هل لك ان تخبرني كيف اصل الي مركز لنكن؟
# Predicted: Could you tell me how to get to Lincoln center?
# True:      Can you tell me how to get to Lincoln Center?
# --------------------------------------------------------------------------------
# Arabic:    انا لست متعبا علي الاطلاق.
# Predicted: I'm not tired at all.
# True:      I'm not tired at all.
# --------------------------------------------------------------------------------
# Arabic:    صحح الاخطاء ، ان وجدت.
# Predicted: Correct the errors, if there is one.
# True:      Correct the mistakes, if there are any.
# --------------------------------------------------------------------------------
# Arabic:    احفظ هذه الاسماء عن ظهر قلب.
# Predicted: These names will be learned by heart.
# True:      Learn these names by heart.
# --------------------------------------------------------------------------------
# Arabic:    سيتزوجا الشهر القادم.
# Predicted: They're getting married next month.
# True:      They will get married next month.
# --------------------------------------------------------------------------------
# Arabic:    انا متفرغ الان
# Predicted: I'm free now.
# True:      I'm free now.
# --------------------------------------------------------------------------------
# Arabic:    لكل جواد كبوه.
# Predicted: Even Homer sometimes nods.
# True:      Even Homer sometimes nods.
# --------------------------------------------------------------------------------
# Arabic:    كانت مشغوله بانهاء واجباتها.
# Predicted: She was busy doing her homework.
# True:      She was busy doing her homework.
# --------------------------------------------------------------------------------
# Arabic:    فقط اخبريني ماذا تريدين.
# Predicted: Just tell me what you want.
# True:      Just tell me what you want.
# --------------------------------------------------------------------------------
# Arabic:    احلم كثيرا.
# Predicted: I have a lot of dreams.
# True:      I have a lot of dreams.
# --------------------------------------------------------------------------------
# Arabic:    ساستحم.
# Predicted: I'm going to take a bath.
# True:      I'll take a shower.
# --------------------------------------------------------------------------------
# Arabic:    ايمكننا الوثوق بك؟
# Predicted: Can we trust you?
# True:      Can we trust you?
# --------------------------------------------------------------------------------
# Arabic:    بامكانك وضعها في اي مكان.
# Predicted: You can put it anywhere.
# True:      You can put it anywhere.
# --------------------------------------------------------------------------------
# Arabic:    اعتقد بانه يمكننا مساعده بعضنا البعض.
# Predicted: I think we can help each other.
# True:      I think we can help each other.
# --------------------------------------------------------------------------------
# Arabic:    لديها خمسه اخوان كبار.
# Predicted: She has five older brothers.
# True:      She has five older brothers.
# --------------------------------------------------------------------------------
# Arabic:    هل تلك امك؟
# Predicted: Is that your mother?
# True:      Is that your mom?
# --------------------------------------------------------------------------------
# Arabic:    اتي ولدي الي غرفتي.
# Predicted: My son came to my room.
# True:      My son came to my room.
# --------------------------------------------------------------------------------
# Arabic:    شكرا لك علي المعلومه.
# Predicted: Thank you for the information.
# True:      Thank you for the information.
# --------------------------------------------------------------------------------
# Arabic:    يا له من قوس قزح جميل!
# Predicted: What a beautiful rainbow!
# True:      What a beautiful rainbow!
# --------------------------------------------------------------------------------
# Arabic:    البعد يزيد القلب ولوعا.
# Predicted: The distance makes the heart worse.
# True:      Absence makes the heart grow fonder.
# --------------------------------------------------------------------------------
# Arabic:    في اي وقت تخرج من عملك؟
# Predicted: What time do you leave your job?
# True:      What time do you leave your work?
# --------------------------------------------------------------------------------
# Arabic:    كان يوجد جسر هنا في يوم من الايام.
# Predicted: There used to be a bridge here.
# True:      At one time, there was a bridge here.
# --------------------------------------------------------------------------------
# Arabic:    قام بالعمل كما طلب.
# Predicted: He did the work as he wanted.
# True:      He accomplished the work as planned.
# --------------------------------------------------------------------------------
# Arabic:    دعونا ننقسم.
# Predicted: Let's split.
# True:      Let's split.
# --------------------------------------------------------------------------------
# Arabic:    اذهب الي المدرسه.
# Predicted: I go to school.
# True:      I go to school.
# --------------------------------------------------------------------------------
# Arabic:    اخبر توم باني مشغول.
# Predicted: Tom told me I was busy.
# True:      Tell Tom that I'm busy.
# --------------------------------------------------------------------------------
# Arabic:    ما الذي تخشاه ؟
# Predicted: What are you frightened of?
# True:      What are you afraid of?
# --------------------------------------------------------------------------------
# Arabic:    لم يكن هناك احتمال لنجاحه.
# Predicted: There was no possibility of his success.
# True:      He couldn't possibly succeed.
# --------------------------------------------------------------------------------
# Arabic:    توم يحب ان يقرا
# Predicted: Tom loves reading.
# True:      Tom likes to read.
# --------------------------------------------------------------------------------
# Arabic:    المستشفي مزدحم.
# Predicted: The hospital is crowded.
# True:      The hospital is crowded.
# --------------------------------------------------------------------------------
# Arabic:    تعجبني سيارتك.
# Predicted: I like your car.
# True:      I like your car.
# --------------------------------------------------------------------------------
# Arabic:    يستيقظ جدي باكرا.
# Predicted: My grandfather is getting up early.
# True:      My grandfather gets up early.
# ...
# Arabic:    من الواضح انك مخطي.
# Predicted: It is clear that you are mistaken.
# True:      Clearly you are mistaken.
# --------------------------------------------------------------------------------
# Arabic:    عليك الا تذهب الي هناك.
# Predicted: You shouldn't go there.
# True:      You should not go there.
# --------------------------------------------------------------------------------
# Arabic:    هذا الكرسي قبيح.
# Predicted: This chair is ugly.
# True:      This chair is ugly.
# --------------------------------------------------------------------------------
# Arabic:    ليس لدي نقود
# Predicted: I don't have money.
# True:      I do not have any money.
# --------------------------------------------------------------------------------
# Arabic:    ايوجد صراف الي بالقرب من هنا؟
# Predicted: Is there a changer around here?
# True:      Is there a cash machine near here?
# --------------------------------------------------------------------------------
# Arabic:    هي ترتدي خاتما قيما.
# Predicted: She wears a value ring.
# True:      She is wearing a valuable ring.
# --------------------------------------------------------------------------------
# Arabic:    لو كان عندي سياره لذهبت الي المكتبه.
# Predicted: If I had a car, I would go to the library.
# True:      I would go to the library if I had a car to get there.
# --------------------------------------------------------------------------------
# Arabic:    اتظن ان توم اشتراها؟
# Predicted: Do you think Tom bought it?
# True:      Do you think Tom bought it?
# --------------------------------------------------------------------------------
# Arabic:    هذا الصندوق ليس كبيرا كذاك.
# Predicted: This box is not as large as that.
# True:      This box is not as big as that one.
# --------------------------------------------------------------------------------
# Arabic:    شكرا لك علي الامسيه الممتعه.
# Predicted: Thank you for the pleasant evening.
# True:      Thank you for the pleasant evening.
# --------------------------------------------------------------------------------
# Arabic:    السناجب سريعه الحركه.
# Predicted: Squirts are fast.
# True:      Squirrels move quickly.
# --------------------------------------------------------------------------------
# Arabic:    لدي الكثير من العمل لانجزه.
# Predicted: I have a lot of work to do.
# True:      I have a lot of work to do.
# --------------------------------------------------------------------------------
# Arabic:    احدهم علي الباب.
# Predicted: Someone is on the door.
# True:      Someone is at the front door.
# --------------------------------------------------------------------------------
# Arabic:    ماذا تقصد؟
# Predicted: What do you mean?
# True:      What do you mean?
# --------------------------------------------------------------------------------
# Arabic:    انه وصل مع فتاه حسناء علي ذراعه.
# Predicted: He got a pretty girl on his arm.
# True:      He arrived with a pretty girl on his arm.
# --------------------------------------------------------------------------------
# Arabic:    انت لديك انف كبير.
# Predicted: You have a big nose.
# True:      You have a big nose.
# --------------------------------------------------------------------------------
# Arabic:    المعذره علي الازعاج.
# Predicted: I'm sorry for the noise.
# True:      Sorry for the interruption.
# --------------------------------------------------------------------------------
# Arabic:    خطه رديء.
# Predicted: A bad plan.
# True:      His handwriting is poor.
# --------------------------------------------------------------------------------
# Arabic:    عبر الشاعر عن رغبته الحارقه للمراه التي احبها.
# Predicted: The teacher spoke out of his burning desire for the mirror I loved.
# True:      The poet expressed his burning passion for the woman he loved.
# --------------------------------------------------------------------------------
# Arabic:    الغايه تبرر الوسيله.
# Predicted: The extreme explaines the method.
# True:      The end justifies the means.
# --------------------------------------------------------------------------------
# Arabic:    قد سبق واكلوا.
# Predicted: They have already eaten.
# True:      They've already eaten.
# --------------------------------------------------------------------------------
# Arabic:    يجب ان تجهز نفسك بسرعه.
# Predicted: You need to get yourself ready quickly.
# True:      You must get ready quickly.
# --------------------------------------------------------------------------------
# Arabic:    انظر الي تلك الغيوم السوداء.
# Predicted: Look at those black clouds.
# True:      Look at those black clouds.
# --------------------------------------------------------------------------------
# Arabic:    هل لي ان استعير مظلتك؟
# Predicted: May I borrow your umbrellas?
# True:      Can I borrow your umbrella?
# --------------------------------------------------------------------------------
# Arabic:    اين اقرب فندق؟
# Predicted: Where's the nearest hotel?
# True:      Where's the nearest hotel?
# --------------------------------------------------------------------------------
# Arabic:    اي طفل يعرف ذلك.
# Predicted: Any child knows that.
# True:      Any child knows it.
# --------------------------------------------------------------------------------
# Arabic:    كانت فخوره للغايه بوالدها.
# Predicted: She was very proud of her father.
# True:      She was very proud of her father.
# --------------------------------------------------------------------------------
# Arabic:    توم صديقي.
# Predicted: Tom is my friend.
# True:      Tom is my friend.
# --------------------------------------------------------------------------------
# Arabic:    لقد عوقبوا علي جرايمهم.
# Predicted: They were punished for their crimes.
# True:      They were punished for their crimes.
# --------------------------------------------------------------------------------
# Arabic:    لا يمكنني تحدث اليابانيه.
# Predicted: I can't speak Japanese.
# True:      I don't speak Japanese.
# --------------------------------------------------------------------------------
# Arabic:    لولا مساعدتك لفشل ابي.
# Predicted: If it hadn't been for your help, my father would have failed.
# True:      If it had not been for your help, my father would have failed.
# --------------------------------------------------------------------------------
# Arabic:    ينظر اهل الارياف الي الغرباء عاده نظره شبهه.
# Predicted: The people of the rear usually look like strangers.
# True:      Country people are traditionally suspicious of strangers.
# --------------------------------------------------------------------------------
# Arabic:    لكان امرا مسليا.
# Predicted: It would have been fun.
# True:      That would've been fun.
# --------------------------------------------------------------------------------
# Arabic:    يحب الموسيقي.
# Predicted: He likes music.
# True:      He loves music.
# --------------------------------------------------------------------------------
# Arabic:    اين ابي؟
# Predicted: Where's my dad?
# True:      Where's my father?
# --------------------------------------------------------------------------------
# Arabic:    اظن انه يمكنني ان اساعد.
# Predicted: I think I can help.
# True:      I think maybe I can help.
# --------------------------------------------------------------------------------
# Arabic:    انت يمكنك ان تناديني توم.
# Predicted: You can call me Tom.
# True:      You can call me Tom.
# --------------------------------------------------------------------------------
# Arabic:    يجب ان تستخدم الباب الخلفي ريثما يجري صبغ البيت .
# Predicted: You should use the rear door until the house is painted.
# True:      You'll have to use the rear door while the house is being painted.
# --------------------------------------------------------------------------------
# Arabic:    كان هناك حادث سياره بالامس.
# Predicted: There was a car accident yesterday.
# True:      There was a car accident yesterday.
# --------------------------------------------------------------------------------
# Arabic:    البقر يعطينا الحليب.
# Predicted: Cows give us milk.
# True:      Cows give us milk.
# --------------------------------------------------------------------------------
# Arabic:    كنت في الجبال .
# Predicted: I was in the mountains.
# True:      I was in the mountains.
# --------------------------------------------------------------------------------
# Arabic:    دفع توم ماري من علي الدرج.
# Predicted: Tom paid Mary off the stairs.
# True:      Tom pushed Mary down the stairs.
# --------------------------------------------------------------------------------
# Arabic:    في ست واربعين سنه بني هذا الهيكل.
# Predicted: At forty-six years, this temple was built.
# True:      It has taken forty-six years to build this temple.
# --------------------------------------------------------------------------------
# Arabic:    انا موقن بان توم محق.
# Predicted: I'm sure Tom's right.
# True:      I believe Tom is right.
# --------------------------------------------------------------------------------
# Arabic:    لم لا تاكل خضارا؟
# Predicted: Why not eat vegetables?
# True:      Why don't you eat vegetables?
# --------------------------------------------------------------------------------
# Arabic:    كلاهما في الغرفه.
# Predicted: Both of them are in the room.
# True:      Both of them are in the room.
# --------------------------------------------------------------------------------
# Arabic:    تحمل الفيران الطاعون.
# Predicted: Rats carry the oven.
# True:      Rats carry the plague.
# --------------------------------------------------------------------------------
# Arabic:    الحياه جميله.
# Predicted: Life is beautiful.
# True:      Life is beautiful.
# --------------------------------------------------------------------------------
# Arabic:    يمكن ان تحدث الزلازل في اي لحظه.
# Predicted: Earthquakes can take place anytime.
# True:      Earthquakes may occur at any moment.
# --------------------------------------------------------------------------------
# Arabic:    باركت له علي نجاحه.
# Predicted: She congratulate him on his success.
# True:      I congratulated him on his success.
# --------------------------------------------------------------------------------
# Arabic:    هنا حيث توم يركن سيارته غالبا.
# Predicted: This is where Tom often parkes his car.
# True:      This is where Tom usually parks his car.
# --------------------------------------------------------------------------------
# Arabic:    هو اصم، لكنه يعرف كيف يقرا الشفاه.
# Predicted: He is deaf, but he knows how to read a word.
# True:      He is deaf, but knows how to read lips.
# --------------------------------------------------------------------------------
# Arabic:    هو دعاني الي منزله.
# Predicted: He invited me home.
# True:      He invited me to his house.
# --------------------------------------------------------------------------------
# Arabic:    تخصصي هو تاريخ اوروبا في العصور الوسطي.
# Predicted: My specialty is the history of Europe in the medieval.
# True:      My major is medieval European history.
# --------------------------------------------------------------------------------
# Arabic:    اريني جواز سفرك، لو سمحت.
# Predicted: Show your passport, please.
# True:      Show me your passport, please.
# --------------------------------------------------------------------------------
# Arabic:    الانترنت مصدر معلومات لا يقدر بثمن.
# Predicted: The Internet is an priceless information source.
# True:      The Internet is an invaluable source of information.
# --------------------------------------------------------------------------------
# Arabic:    اعتقد ان ما تقوله صحيح.
# Predicted: I believe what you said is true.
# True:      I think you're right.
# --------------------------------------------------------------------------------
# Arabic:    هل تري هذا؟
# Predicted: Do you see this?
# True:      Do you see that?
# --------------------------------------------------------------------------------
# Arabic:    انها صعبه في البدايه.
# Predicted: It's difficult at first.
# True:      At first, it is difficult.
# --------------------------------------------------------------------------------
# Arabic:    الا يمكنك تكلم الانجليزيه؟
# Predicted: Can't you speak English?
# True:      Can't you speak English?
# --------------------------------------------------------------------------------
# Arabic:    تحدث الرجل بصوت منخفض.
# Predicted: The man spoke low.
# True:      The man spoke in a low voice.
# --------------------------------------------------------------------------------
# Arabic:    لم يكن هذا مهذبا.
# Predicted: That wasn't polite.
# True:      That wasn't nice.
# --------------------------------------------------------------------------------
# Arabic:    كم هذا مزعج!
# Predicted: How annoying!
# True:      How annoying!
# --------------------------------------------------------------------------------
# Arabic:    يا لها من راحه
# Predicted: What a relief!
# True:      What a relief!
# --------------------------------------------------------------------------------
# Arabic:    هو سعيد
# Predicted: He's happy.
# True:      He's happy.
# --------------------------------------------------------------------------------
# Arabic:    ترجم الجمل التي تحتها خط.
# Predicted: Translate the sentences underneath the line.
# True:      Translate the underlined sentences.
# --------------------------------------------------------------------------------
# Arabic:    ما الذي يقلقك؟
# Predicted: What is troubling you?
# True:      What are you concerned about?
# --------------------------------------------------------------------------------
# Arabic:    لم يعد لدي الا واحده.
# Predicted: I only have one.
# True:      I've only got one left.
# --------------------------------------------------------------------------------
# Arabic:    اصبت بالزكام.
# Predicted: I've caught colds.
# True:      I have a cold.
# --------------------------------------------------------------------------------
# Arabic:    هذا الموقع مفيد جدا.
# Predicted: This website is very useful.
# True:      This website is very useful.
# --------------------------------------------------------------------------------
# Arabic:    السكين ليست حاده.
# Predicted: The knife is not sharp.
# True:      The knife is not sharp.
# --------------------------------------------------------------------------------
# Arabic:    لا يهمني اذا هطل الثلج.
# Predicted: I don't care if it snows.
# True:      I don't care if it snows.
# --------------------------------------------------------------------------------
# Arabic:    ما هو تاريخ ميلادك؟
# Predicted: What is your date of birth?
# True:      What is your date of birth?
# --------------------------------------------------------------------------------
# Arabic:    اعارني كتابين.
# Predicted: He lend me two books.
# True:      He lent me two books.
# --------------------------------------------------------------------------------
# Arabic:    هو قاري نهم.
# Predicted: He is a greasy boat.
# True:      He reads a good deal.
# --------------------------------------------------------------------------------
# Arabic:    تاخرت بسبب زحمه الطريق الشديده.
# Predicted: I was late because of the hard road.
# True:      I was late because of heavy traffic.
# --------------------------------------------------------------------------------
# Arabic:    علي الاختباء.
# Predicted: I have to hide.
# True:      I must hide.
# --------------------------------------------------------------------------------
# Arabic:    هو تركنا نذهب.
# Predicted: He lets us go.
# True:      He let us go.
# --------------------------------------------------------------------------------
# Arabic:    ما الذي تتحدث عنه؟
# Predicted: What are you talking about?
# True:      What're you talking about?
# --------------------------------------------------------------------------------
# Arabic:    شعرت بالحزن.
# Predicted: I was sad.
# True:      I felt sad.
# --------------------------------------------------------------------------------
# Arabic:    ساوصلك الي المنزل بالسياره.
# Predicted: I'll drive you home.
# True:      I will drive you home.
# --------------------------------------------------------------------------------
# Arabic:    مدرستنا قريبه من المحطه.
# Predicted: Our school is near the station.
# True:      Our school is near the station.
# --------------------------------------------------------------------------------
# ChrF Score: 71.27545065203786
# BLEU Score: 0.5810126068118645

# %%
# Save the model and tokenizer
model.save_pretrained("./results")
tokenizer.save_pretrained("./results")
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/modeling_utils.py:3339: UserWarning: Moving the following attributes in the config to the generation config: {'max_length': 512, 'num_beams': 4, 'bad_words_ids': [[62833]]}. You are seeing this warning because you've set generation parameters in the model config, as opposed to in the generation config.
#   warnings.warn(
# ('./results/tokenizer_config.json',
#  './results/special_tokens_map.json',
#  './results/vocab.json',
#  './results/source.spm',
#  './results/target.spm',
#  './results/added_tokens.json')

# %%
# Load custom trained model and tokenizer
model_name = "./results"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name).to(device)


def split_text_by_sentences(text, max_chars=600):
    text = re.sub(r'\s+', ' ', text.strip())
    sentences = re.split(r'(?<=[.!?؟]) +', text)
    chunks = []
    current_chunk = ""

    for sentence in sentences:
        if len(current_chunk) + len(sentence) <= max_chars:
            current_chunk += sentence + " "
        else:
            chunks.append(current_chunk.strip())
            current_chunk = sentence + " "
    if current_chunk:
        chunks.append(current_chunk.strip())
    return chunks


def translate_long_text(text, chunk_size=300, batch_size=6):  # Adjusted batch size and chunk size
    # Split the text into chunks
    chunks = split_text_by_sentences(text, max_chars=chunk_size)
    translated_chunks = []

    print(f"\nTotal chunks to translate: {len(chunks)}")

    # chunks in batches
    for i in range(0, len(chunks), batch_size):
        # Get the current batch of chunks
        batch_chunks = chunks[i:i+batch_size]

        # Tokenize the batch
        inputs = tokenizer(batch_chunks, return_tensors="pt", padding=True, truncation=True, max_length=512).to(device)

        try:
            # Generate translation for the batch
            output_ids = model.generate(
                input_ids=inputs['input_ids'],
                attention_mask=inputs['attention_mask'],
                max_length=1024,
                num_beams=5,
                no_repeat_ngram_size=3,
                early_stopping=True,
                do_sample=False
            )

            # Decode the translated output and store
            for output in output_ids:
                translated_text = tokenizer.decode(output, skip_special_tokens=True)
                translated_chunks.append(translated_text)

            print(f"Translated batch {i // batch_size + 1} ({len(batch_chunks)} chunks)")

        except Exception as e:
            print(f"Error in batch {i // batch_size + 1}: {e}")
            continue

    # Join
    final_translation = " ".join(translated_chunks)
    final_translation = re.sub(r'\s+', ' ', final_translation).strip()

    return final_translation

# %%
arabic_text = input("Please enter the Arabic text to translate: ")

# translation
translated_text = translate_long_text(arabic_text, chunk_size=300, batch_size=6)
print("\nTranslated Text:\n", translated_text)
# Out:
# Please enter the Arabic text to translate: لقد تغير الطب كثيرًا في السنوات القليلة الماضية، وذلك بفضل التقدم التكنولوجي والعلم. وقد أدت هذه التغييرات إلى تحسين طرق غسيل الكلى وعلاجها، وزيادة مستويات التعافي من العديد من الأمراض التي كان يُنظر إليها على أنها صعبة في المستقبل. وأصبح الطبيب الآن قادراً على استخدام تقنيات مثل الذكاء الاصطناعي والسراويل في هذه العملية، مما يزيد من سرعة العمل الطبي وتعافي المرضى. ومع ذلك، لا تزال هناك بعض التحديات فيما يتعلق بتكلفة الرعاية الصحية وحصول الجميع عليها، الأمر الذي يتطلب استجابات جديدة وسياسات عادلة لضمان استفادة الجميع من هذه النتائج.
#
# Total chunks to translate: 3
# Translated batch 1 (3 chunks)
#
# Translated Text:
#  medicine has changed a lot in the past few years, thanks to technological advance and science. These changes have improved dialysis and treatment, and have improved levels of recovery from many diseases that were seen as difficult in the future. The doctor is now able to use such techniques as artificial smarts and pants in this process, increasing the speed of medical work and the recovery of patients. There are, however, some challenges regarding the cost of and universal access to health care, which require new responses and just policies to guarantee that these results are available to everyone.
